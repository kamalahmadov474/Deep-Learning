# %% [markdown]
# <a href="https://colab.research.google.com/github/kamalahmadov474/Deep-Learning/blob/main/Finger_Sign_Detection_Using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STEP 1: Importing necessary libraries

# %%
import h5py
import time
import torch
import matplotlib.pyplot as plt
import math

import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
# Out:
# cpu

# %% [markdown]
# STEP 2: Extract Dataset

# %%
def h5_to_tensor(h5_file_path):
    dataset_tensor = {}

    with h5py.File(h5_file_path, 'r') as h5:
        keys = list(h5.keys())

        for key in keys:
            data = h5[key][:]
            dataset_tensor[key] = torch.from_numpy(data)

    return dataset_tensor

# %%
training_data = h5_to_tensor("/content/Signs_Data_Testing.h5")

print(training_data.keys())
# Out:
# dict_keys(['list_classes', 'test_set_x', 'test_set_y'])

# %%
X_train = training_data["test_set_x"].to(device)
y_train = training_data["test_set_y"].to(device)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# X_train shape: torch.Size([120, 64, 64, 3])
# y_train shape: torch.Size([120])

# %%
testing_data = h5_to_tensor("/content/Signs_Data_Testing.h5")

print(testing_data.keys())
# Out:
# dict_keys(['list_classes', 'test_set_x', 'test_set_y'])

# %%
X_test = testing_data["test_set_x"].to(device)
y_test = testing_data["test_set_y"].to(device)

print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_test shape: torch.Size([120, 64, 64, 3])
# y_test shape: torch.Size([120])

# %% [markdown]
# STEP 3: Data Preprocessing

# %%
# Check if there is any NaN values

print(X_train.isnan().sum())
print(y_train.isnan().sum())
# Out:
# tensor(0)
# tensor(0)

# %%
# Set of classes
# According to data, there are data which belongs to either one of 6 classes: [0, 1, 2, 3, 4, 5]

y_train.unique()
# Out:
# tensor([0, 1, 2, 3, 4, 5])

# %%
# Display images

def display_images(images, labels):
    cols = 4
    rows = math.ceil(len(images) / cols)
    plt.figure(figsize=(20, 10))
    index = 0

    for x in zip(images, labels):
        image = x[0].cpu()
        label = x[1].cpu()
        plt.subplot(rows, cols, index + 1)
        plt.imshow(image, cmap='gray')
        plt.title(f"Label: {label}")
        # plt.axis("off")
        index += 1

# %%
import random

indices = [random.randint(0, X_train.shape[0]) for _ in range(5)]
images = [X_train[index] for index in indices]
labels = [y_train[index] for index in indices]

display_images(images, labels)

# %% [markdown]
# STEP 4: Custom Dataset

# %%
class CustomDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %% [markdown]
# STEP 5: Build the CNN Model

# %%
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()

        # Input image size: 64 * 64 * 3 (3 channels)

        # Layer Set 1: Convolutional Layer -> ReLU Layer -> Pooling Layer
        self.conv_layer_1 = nn.Conv2d(3, 32, kernel_size=5, stride=1, padding=2)
        self.bn_1 = nn.BatchNorm2d(32)
        self.relu_1 = nn.ReLU()

        self.max_pool_1 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Layer Set 2: Conv Layer -> ReLU Layer -> Max Pool Layer
        self.conv_layer_2 = nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2)
        self.bn_2 = nn.BatchNorm2d(64)
        self.relu_2 = nn.ReLU()

        self.max_pool_2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Fully Connected layers: Input (509 neurons) -> FC 1 (256 neurons) with ReLU -> FC 2 (128 neurons) with ReLU -> FC 3/Output (6 classes)
        self.fc_1 = nn.Linear(in_features=16*16*64, out_features=256)
        self.fc_1_relu = nn.ReLU()
        self.dropout_1 = nn.Dropout(0.2)

        self.fc_2 = nn.Linear(in_features=256, out_features=128)
        self.fc_2_relu = nn.ReLU()
        self.dropout_2 = nn.Dropout(0.2)

        self.fc_3 = nn.Linear(in_features=128, out_features=6)

    def forward(self, X):
        # Conv Layer 1
        out = self.conv_layer_1(X)
        out = self.bn_1(out)
        out = self.relu_1(out)

        out = self.max_pool_1(out)

        # Conv Layer 2
        out = self.conv_layer_2(out)
        out = self.bn_2(out)
        out = self.relu_2(out)

        out = self.max_pool_2(out)

        # Flatten
        out = out.reshape(out.size(0), -1)

        # FC Layers
        out = self.fc_1(out)
        out = self.fc_1_relu(out)
        out = self.dropout_1(out)

        out = self.fc_2(out)
        out = self.fc_2_relu(out)
        out = self.dropout_2(out)

        out = self.fc_3(out)

        return out

# %% [markdown]
# STEP 6: Set Hyperparameters

# %%
batch_size = 32
total_epochs = 100
learning_rate = 0.001

# %% [markdown]
# STEP 7: Model Training

# %%
cnn_model = CNNModel().to(device)

# %%
error = nn.CrossEntropyLoss()

# SGD Optimizer
optimizer = torch.optim.SGD(cnn_model.parameters(), lr=learning_rate)

# %%
train_dataset = CustomDataset(X_train, y_train)

train_data = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
num_of_iterations = X_train.shape[0] // batch_size

count = 0
loss_list = []
iteration_list = []

training_start_time = time.time()

for epoch in range(total_epochs):
    for i, (images, labels) in enumerate(train_data):
        images = images.float()
        images = images.permute(0, 3, 1, 2)

        # Clear gradients
        optimizer.zero_grad()

        # Forward pass
        output = cnn_model.forward(images)

        # Calculate loss
        loss = error(output, labels)

        # Backpropagation and calculate gradients
        loss.backward()

        # Update parameters
        optimizer.step()

        count += 1
        loss_list.append(loss)
        iteration_list.append(count)

        if i % 4 == 0:
            print(f"Epoch: [{epoch + 1}/{total_epochs}], step: [{i + 1}/{num_of_iterations}], loss: {loss.data:.4f}")

training_end_time = time.time()

print(f"\nTotal training time: {training_end_time - training_start_time} seconds")
# Out:
# Epoch: [1/100], step: [1/3], loss: 1.8235
# Epoch: [2/100], step: [1/3], loss: 1.7771
# Epoch: [3/100], step: [1/3], loss: 1.7782
# Epoch: [4/100], step: [1/3], loss: 1.7665
# Epoch: [5/100], step: [1/3], loss: 1.7544
# Epoch: [6/100], step: [1/3], loss: 1.7567
# Epoch: [7/100], step: [1/3], loss: 1.7656
# Epoch: [8/100], step: [1/3], loss: 1.7204
# Epoch: [9/100], step: [1/3], loss: 1.7287
# Epoch: [10/100], step: [1/3], loss: 1.7178
# Epoch: [11/100], step: [1/3], loss: 1.7229
# Epoch: [12/100], step: [1/3], loss: 1.7055
# Epoch: [13/100], step: [1/3], loss: 1.7474
# Epoch: [14/100], step: [1/3], loss: 1.7256
# Epoch: [15/100], step: [1/3], loss: 1.6969
# Epoch: [16/100], step: [1/3], loss: 1.6970
# Epoch: [17/100], step: [1/3], loss: 1.6774
# Epoch: [18/100], step: [1/3], loss: 1.6957
# Epoch: [19/100], step: [1/3], loss: 1.6875
# Epoch: [20/100], step: [1/3], loss: 1.6609
# Epoch: [21/100], step: [1/3], loss: 1.6616
# Epoch: [22/100], step: [1/3], loss: 1.6889
# Epoch: [23/100], step: [1/3], loss: 1.6694
# Epoch: [24/100], step: [1/3], loss: 1.6572
# Epoch: [25/100], step: [1/3], loss: 1.6101
# Epoch: [26/100], step: [1/3], loss: 1.6283
# Epoch: [27/100], step: [1/3], loss: 1.5574
# Epoch: [28/100], step: [1/3], loss: 1.6678
# Epoch: [29/100], step: [1/3], loss: 1.5623
# Epoch: [30/100], step: [1/3], loss: 1.5742
# Epoch: [31/100], step: [1/3], loss: 1.6167
# Epoch: [32/100], step: [1/3], loss: 1.5909
# Epoch: [33/100], step: [1/3], loss: 1.6010
# Epoch: [34/100], step: [1/3], loss: 1.5570
# Epoch: [35/100], step: [1/3], loss: 1.5872
# Epoch: [36/100], step: [1/3], loss: 1.5445
# Epoch: [37/100], step: [1/3], loss: 1.5135
# Epoch: [38/100], step: [1/3], loss: 1.5860
# Epoch: [39/100], step: [1/3], loss: 1.4967
# Epoch: [40/100], step: [1/3], loss: 1.5048
# Epoch: [41/100], step: [1/3], loss: 1.5429
# Epoch: [42/100], step: [1/3], loss: 1.5211
# Epoch: [43/100], step: [1/3], loss: 1.5472
# Epoch: [44/100], step: [1/3], loss: 1.4638
# Epoch: [45/100], step: [1/3], loss: 1.5203
# Epoch: [46/100], step: [1/3], loss: 1.4647
# Epoch: [47/100], step: [1/3], loss: 1.4643
# Epoch: [48/100], step: [1/3], loss: 1.4117
# Epoch: [49/100], step: [1/3], loss: 1.3987
# Epoch: [50/100], step: [1/3], loss: 1.3825
# Epoch: [51/100], step: [1/3], loss: 1.4805
# Epoch: [52/100], step: [1/3], loss: 1.3981
# Epoch: [53/100], step: [1/3], loss: 1.3575
# Epoch: [54/100], step: [1/3], loss: 1.3455
# Epoch: [55/100], step: [1/3], loss: 1.3598
# Epoch: [56/100], step: [1/3], loss: 1.3866
# Epoch: [57/100], step: [1/3], loss: 1.4323
# Epoch: [58/100], step: [1/3], loss: 1.3467
# Epoch: [59/100], step: [1/3], loss: 1.2818
# Epoch: [60/100], step: [1/3], loss: 1.2650
# Epoch: [61/100], step: [1/3], loss: 1.2551
# Epoch: [62/100], step: [1/3], loss: 1.2778
# Epoch: [63/100], step: [1/3], loss: 1.3240
# Epoch: [64/100], step: [1/3], loss: 1.2800
# Epoch: [65/100], step: [1/3], loss: 1.2533
# Epoch: [66/100], step: [1/3], loss: 1.2189
# Epoch: [67/100], step: [1/3], loss: 1.2503
# Epoch: [68/100], step: [1/3], loss: 1.3599
# Epoch: [69/100], step: [1/3], loss: 1.2283
# Epoch: [70/100], step: [1/3], loss: 1.3240
# Epoch: [71/100], step: [1/3], loss: 1.2180
# Epoch: [72/100], step: [1/3], loss: 1.1525
# Epoch: [73/100], step: [1/3], loss: 1.1716
# Epoch: [74/100], step: [1/3], loss: 1.2402
# Epoch: [75/100], step: [1/3], loss: 1.2299
# Epoch: [76/100], step: [1/3], loss: 1.1310
# Epoch: [77/100], step: [1/3], loss: 1.2020
# Epoch: [78/100], step: [1/3], loss: 1.1730
# Epoch: [79/100], step: [1/3], loss: 1.0826
# Epoch: [80/100], step: [1/3], loss: 1.1165
# Epoch: [81/100], step: [1/3], loss: 1.2175
# Epoch: [82/100], step: [1/3], loss: 1.0991
# Epoch: [83/100], step: [1/3], loss: 1.0652
# Epoch: [84/100], step: [1/3], loss: 1.0442
# Epoch: [85/100], step: [1/3], loss: 1.0320
# Epoch: [86/100], step: [1/3], loss: 1.0048
# Epoch: [87/100], step: [1/3], loss: 1.1358
# Epoch: [88/100], step: [1/3], loss: 1.0885
# Epoch: [89/100], step: [1/3], loss: 1.0809
# Epoch: [90/100], step: [1/3], loss: 1.0133
# Epoch: [91/100], step: [1/3], loss: 1.0158
# Epoch: [92/100], step: [1/3], loss: 1.0213
# Epoch: [93/100], step: [1/3], loss: 0.9669
# Epoch: [94/100], step: [1/3], loss: 0.9427
# Epoch: [95/100], step: [1/3], loss: 0.9613
# Epoch: [96/100], step: [1/3], loss: 0.9114
# Epoch: [97/100], step: [1/3], loss: 0.9767
# Epoch: [98/100], step: [1/3], loss: 1.0400
# Epoch: [99/100], step: [1/3], loss: 0.8886
# Epoch: [100/100], step: [1/3], loss: 0.9666
#
# Total training time: 101.2490291595459 seconds

# %%
# Loss Graph

loss_list_numpy = [loss.detach().cpu().numpy() for loss in loss_list]

plt.plot(iteration_list, loss_list_numpy)

plt.xlabel("Iterations")
plt.ylabel("Loss")

plt.title("CNN: Loss Graph")

plt.show()

# %% [markdown]
# STEP 8: Model Evaluation

# %%
test_dataset = CustomDataset(X_test, y_test)

test_data = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
with torch.no_grad():
    total_test = 0
    total_correct = 0

    for i, (images, labels) in enumerate(test_data):
        images = images.float()
        images = images.permute(0, 3, 1, 2)

        output = cnn_model.forward(images)

        _, predictions = torch.max(output, 1)

        total_correct += (predictions == labels).sum().item()
        total_test += labels.shape[0]

print(f"Total correct predictions: {total_correct}")
print(f"Total samples: {total_test}")
print(f"Accuracy: {total_correct / total_test * 100:.3f}%")
# Out:
# Total correct predictions: 107
# Total samples: 120
# Accuracy: 89.167%

# %%
# Prediction function

def predict(image):
    # Add a batch dimension at the beginning (shape: 1, H, W, C)
    image = image.unsqueeze(0)

    image = image.float()
    image = image.permute(0, 3, 1, 2)

    cnn_model.eval()
    with torch.no_grad():
        output = cnn_model.forward(image)

    _, prediction = torch.max(output, 1)

    return prediction

# %% [markdown]
# STEP 9: Test Examples

# %%
random_indices = [random.randint(0, X_test.shape[0] - 1) for _ in range(10)]

images = [X_test[idx] for idx in random_indices]
labels = [y_test[idx] for idx in random_indices]

predicted_labels = [predict(image) for image in images]

rows = 2
columns = 5
plt.figure(figsize=(20, 10))

for i, (image, label, predicted_label) in enumerate(zip(images, labels, predicted_labels)):
    plt.subplot(rows, columns, i + 1)
    plt.imshow(image.cpu())
    plt.title(f"Actual label: {label}\nPredicted label: {predicted_label[0]}")
